# %% [markdown]
# <a href="https://colab.research.google.com/github/PierluigiRiti2/ComputerVision/blob/main/Etivity_assignment2_Pierluigi_Riti_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Etivity 2: Deep Convolutional Neural Network on CIFAR-10 Dataset
#
# In this assignment, we will gain some practical experience of coding a deep convolutional neural network in Tensorflow. The simplest way to code a network is to use the High level Keras API within Tensorflow 2.5.
#
# ## (a) Introduction
#
#  In this assignment to reduce training time and computation, we will train our network using the simple [CIFAR10](https://www.cs.toronto.edu/~kriz/cifar.html) dataset.
# ![link text](https://paperswithcode.com/media/datasets/CIFAR-10-0000000431-b71f61c0_U5n3Glr.jpg)
#
# The goal of this Etivity is to build and train your own Deep Convolutional Neural Network. This notebook contains standard keras/Tensorflow code to perform data processing, training set up and testing metrics, as outlined in the steps below. This will allow you to focus on developing the architecture & code for your network.
#
# 1. Load Dataset - We will import the CIFAR-10 Dataset using the Tensorflow Data Set API.
# 2. Prepare Data - We will slightly modify the dataset before it is sent to the model for training.
# 3. Model Coding - We will write code to build the model using the Tensorflow keras API.
#   * **You will code your neural network model in this section**
# 4. Compile Model - We will complile the model and verify that it has been correctly constructed.
# 5. Train Model - We will train the model using the imported dataset.
# 6. Test Model - We test the model on the training data and obtain a classification report and confusion matrix.
#
# The principal resource for understanding the basics of how to code & train Deep Convolutional Neural Network architectures in Tensorflow/keras are the Tensorflow tutorials. Tutorials on [image classification](https://www.tensorflow.org/tutorials/images/classification) and [data augmentation](https://www.tensorflow.org/tutorials/images/data_augmentation) are useful for this Etivity.

# %% [markdown]
# ## (b) Notes on Architecture selection & development
#
# A key task in this Etivity is selecting an appropriate architecture. You can base your archicture on any of the types seen in the lecture notes or published literature. It is however recommended to ensure you can get a standard CNN type architecture to successfully train before attempting a more complex architecture or adding further enhancements to your network to improve performance.
#    Many published networks are designed to work with larger sized input images (e.g. 224 x 224). Often large (e.g. 7 x 7) convolution kernels and pooling layers are first applied to the input image, which agressively reduce the spatial dimensions of the network. As the CIFAR-10 dataset only has 32 x 32 images, it is recommended that just an intial 3 x 3 convolution is applied to the input image (as shown in the figure below), which will preserve the spatial dimensions of the input, before any other layers are added. It is expected that as you add more layers to the network the spatial dimensions will reduce and there will also be a corresponding increase the number of channels of the output feature map. The architecture will end with a [global average pooling layer](https://arxiv.org/pdf/1312.4400.pdf) and a fully-connected layer (called a *dense* layer in Keras/Tensorflow) with softmax activation which gives us our 10 class predictions. A skeleton code has been provided for any general architure using this structure in section 3.
# ![link text](https://github.com/tonyscan6003/CE6003/blob/master/images/Architecture_outline.jpg?raw=true)

# %% [markdown]
# #House Keeping

# %%
from __future__ import print_function

# %tensorflow_version 2.x
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras as keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, RandomTranslation, RandomFlip
from tensorflow.keras.layers import GlobalMaxPooling2D, MaxPooling2D
from tensorflow.keras.layers import GlobalAveragePooling2D,AveragePooling2D
from tensorflow.keras.layers import Input, Flatten, Dropout, Add
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.callbacks import LearningRateScheduler

import numpy as np

# %% [markdown]
# To ensure this assignment runs as fast as possible, from the menu above select **Edit > Notebook settings** or **Runtime > Change runtime type** and select GPU as the Hardware accelerator option.
#
# Let's test that we are running using the GPU.

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# #1. Load Dataset
#
# In this assignment, we will be using the [CIFAR-10 dataset](http://www.cs.toronto.edu/~kriz/cifar.htmlhttps://). CIFAR-10 is often used as a "Hello World" dataset that is often used to ensure a network architecture is working before moving on to training with more complex datasets.
#
# The CIFAR-10 dataset consists of 60,000 32x32 color images in 10 classes (airplane, automobile, **bird**, cat, deer, dog, frog, horse, ship, truck), with 6,000 images per class. There are 50,000 training images and 10,000 test images.
#
# We will use the [Tensorflow dataset](https://www.tensorflow.org/datasets/catalog/cifar10) API to download the CIFAR10 dataset.

# %%
batch_size = 32 # Default Batch size (can be adjusted)
H_trg =32       # Image Height (fixed)
W_trg =32       # image Width (fixed)

# Labels corresponding to categories
label_str = ('airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# We initally load the raw training/validation/test dataset
import tensorflow_datasets as tfds
ds,info= tfds.load("cifar10",with_info=True)

raw_train = tfds.load('cifar10', split='train[0%:90%]')
raw_val = tfds.load('cifar10', split='train[91%:100%]')
raw_test = tfds.load('cifar10', split='test')

# %% [markdown]
# # 2. Prepare Data
#
# After importing raw datasets using tfds load, we create an input pipeline that processes & batches this data before it is supplied to the model for training using the virtual machine GPU.

# %%
def data_pipe(image,label):
  image = tf.image.convert_image_dtype(image, tf.float32) # Cast and normalize the image to [0,1]
  image = image-0.5
  label = tf.cast(label, tf.float32)
  return image,label

# %%
def gen_tr_datasets(src_dataset):    
    # Define Datasets 
    #src_dataset = src_dataset.shuffle(num_train_examples) 
    tr_dataset = src_dataset.map(lambda x: (x['image'],x['label']))  
    tr_dataset = tr_dataset.map(data_pipe)
    tr_dataset = tr_dataset.batch(batch_size) 
    return tr_dataset

def gen_val_datasets(src_dataset): 
    # Define Datasets 
    test_dataset = src_dataset.map(lambda x: (x['image'],x['label']))  
    test_dataset = test_dataset.map(data_pipe)
    test_dataset = test_dataset.batch(batch_size) 
    return test_dataset
# Generate the datasets
train_dataset = gen_tr_datasets(raw_train)
val_dataset = gen_val_datasets(raw_val)
test_dataset = gen_val_datasets(raw_test)

# %% [markdown]
# Plot some examples of the training dataset.

# %%
i=0
n_plots = 12 # number of plots
f, axarr = plt.subplots(1,n_plots,figsize=(20,10))

for image, label in train_dataset.take(n_plots):  # Only take a single example
  #axarr[i].imshow(image[0,:,:,:]+128)
  axarr[i].imshow(image[0,:,:,:]+0.5) # Fix the error with Colab
  axarr[i].axis('off')
  axarr[i].title.set_text(label_str[int(label[0])])
  i = i+1

# %% [markdown]
# # 3. Model Coding
#
# In this section You may develop your own model architecture to perform image recognition with the CIFAR-10 Dataset.
#
# There are some recommendations and helper code in this section that you may choose use, or you can also use your own approach to creating your architecture.
#
# Please Leave a note at the end of the notebook explaining your approach/results for the e-moderator.

# %% [markdown]
#
# ## Note 1: Keras Function/Sequential API
#
# Within Keras there are two API's for coding network models: Sequential and functional. You may have already used the [seqential model](https://https://www.tensorflow.org/guide/keras/sequential_model) to code basic artifical neural networks. The [functional model](https://www.tensorflow.org/guide/keras/functional) is more general and enables us to include feedforward paths which are required to code more advanced networks such as ResNet or DenseNet. The functional API has been used to code the helper functions repeating unit/top level skeleton detailed below.
#
# ## Note 2: Repeating Unit
#
# In many Deep architectures there will often be a repeating unit(s) that is composed of a sequence of layers, for example Conv,ReLU & Batch Normalisation. Specific layers can be turned on or off as required. This also allows experimentation of the entire architecture with/without specific layers (e.g. Batch Normalisation)  You may wish to create other combinations of layers or additional repeating units depending on your architecture.
#
# In the code cell below we can see an example of a `repeat_unit` function where the number of kernel filters and kernel size is specified. Batch Normalisation and activation layers can be turned on/off as required.
#
#  * Convolutional Layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D)
#  * Batch Normalization layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization)
#  * Activation layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Activation)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 80:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 60:
        lr *= 1e-2
    elif epoch > 40:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr
  
learning_rates = LearningRateScheduler(lr_schedule)

# %%
# Example of a Basic Repeating unit

def repeat_unit(inputs, num_channels=16, kernel_size=3,
                strides=1, activation='relu', 
                batch_normalization=False,
                conv_first=False):
    """
    inputs: Input to repeat unit.
    num_channels: number of channels in convolution layer of repeat unit, nominally = 16
    kernel_size: number of kernels to use in convolution, nominally = 3
    strides: number of strides for kernel, nominally = 1
    activation: type of activation applied to output of convolution, nominally ReLU.
    conv_first : is used for indicate if is the first layer 
    x = output of repeat_unit
    """

    conv = Conv2D(num_channels, 
                  kernel_size=kernel_size, 
                  strides=strides, 
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))
    
    x = conv(inputs)
    
    if activation is not None:
        x = Activation(activation)(x)

    if batch_normalization:
        x = BatchNormalization()(x)
    
    return x

# %% [markdown]
# ## Note 3: Top Level
#
# In the code cell below, an incomplete skeleton function is provided for your top level.
# * This uses the Keras functional API
# * A single repeating unit which does not reduce the spatial dimensions of the input is placed at the top of the stack. You can change the number of channels/kernel size to suit your own architecture.
# * You can add your own layers/repeating units etc to build your own architecture with the function.
# * At the end of the stack we add a [global average pooling layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/GlobalAveragePooling2D) and fully connected [(Dense)](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) layer with softmax activation. (Alternatively to the Global Average pooling Dense layers can be used, this approach uses more parameter (memory) and is commonly seen in earlier Deeep Learning architectures such as AlexNet)

# %%
def resnet_block(inputs, num_channels=64, kernel_size=3, strides=1):
  """
  inputs: Input to resnet unit.
  num_channels: number of channels in convolution layer of repeat unit, nominally = 16
  kernel_size: number of kernels to use in convolution, nominally = 3
  strides: number of strides for kernel, nominally = 1
  activation: type of activation applied to output of convolution, nominally ReLU. 
  x = output of resnet_unit
  """
  skip = inputs

  # Convolutional path
  conv1 = Conv2D(num_channels, 
                 kernel_size=kernel_size, 
                 strides=strides, 
                 padding='same',
                 activation='relu', 
                 kernel_initializer='he_normal',
                 kernel_regularizer=l2(1e-4))(inputs)
  conv1 = BatchNormalization()(conv1)

  conv2 = Conv2D(num_channels, 
                 kernel_size=kernel_size, 
                 strides=strides, 
                 padding='same',
                 kernel_initializer='he_normal',
                 kernel_regularizer=l2(1e-4))(conv1)

  conv2 = BatchNormalization()(conv2)

  x = Add() ([skip, conv2])

  x = Activation('relu')(x)

  return x

# %%
def network_top(input_shape,num_classes=10):
    """
    input Shape: (Define H,W, no. channels) of network input
                 used in Input definition below
    num_classes: Default = 10, sets output classes of network,
                 set to same no. of classes as CIFAR 10 Dataset 
    model:       keras Model returned by this function.                          
    """
       
    # Define input of model
    inputs = Input(shape=input_shape)

    #Add the data argumentation
    data_augmentation = tf.keras.Sequential([layers.RandomTranslation(0.1, 0.1, fill_mode='nearest'), RandomFlip("horizontal")])
    x = tf.keras.Sequential(data_augmentation)(inputs)

    # Add First repeating Unit
    #x = repeat_unit(inputs, num_channels=12)
    #x = repeat_unit(inputs, num_channels=16) # chage the size, becuse the number of challenge are 64 not 12

   ######## Add more layers/repeating units to build your Architecture here ################## 
    x = repeat_unit(x, num_channels=16, 
                    batch_normalization=True)
    # create a 3 layer with 16 Channels
    x = resnet_block(x, num_channels=16)
    x = resnet_block(x, num_channels=16)
    x = resnet_block(x, num_channels=16)

    x = repeat_unit(x, num_channels=32, 
                    batch_normalization=True,  
                    conv_first=True)
    # create 3 layers with 32 channels    
    x = resnet_block(x, num_channels=32)
    x = resnet_block(x, num_channels=32)
    x = resnet_block(x, num_channels=32)
    x = resnet_block(x, num_channels=32)

    x = repeat_unit(x, num_channels=64, 
                    batch_normalization=True,  
                    conv_first=True)
    
    # create 4 layer with 64 channels
    x = resnet_block(x, num_channels=64)
    x = resnet_block(x, num_channels=64)
    x = resnet_block(x, num_channels=64)
    x = resnet_block(x, num_channels=64)
    
    # Add final stages. (Ensure that you call the output of the very last layer outputs)
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(x)

    # Model definition
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# # 4. Compile the Model
# Now that we have defined our functions to create the model, we'll instantiate the model and compile it.  Note that the compiling step in Keras, also configures the model for training. We define  loss function, the optimizer and metrics.
#
# Note the use here of [Sparse Categorical Crossentropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy). This loss function allows us to input integer values for true classes. With the regular categorical cross entropy loss function the supplied labels must be frist converted to a one-hot representation,  but this special loss function allows us to avoid manually converting to the one-hot representation.

# %%
input_shape = (32,32,3)
model = network_top(input_shape=input_shape)
model.compile(loss='SparseCategoricalCrossentropy', optimizer=Adam(learning_rate=lr_schedule(0)), metrics=['accuracy'])
model.summary()

# Uncomment the following line to plot the model visually - warning this may be quite large!
#keras.utils.plot_model(model, dpi=48)
# Out:
# Learning rate:  0.001
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  sequential_3 (Sequential)      (None, 32, 32, 3)    0           ['input_2[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 16)   448         ['sequential_3[0][0]']
#
#  activation_15 (Activation)     (None, 32, 32, 16)   0           ['conv2d_26[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 16)  64          ['activation_15[0][0]']
#  ormalization)
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 16)   2320        ['batch_normalization_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 16)  64          ['conv2d_27[0][0]']
#  ormalization)
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 16)   2320        ['batch_normalization_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 16)  64          ['conv2d_28[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 32, 32, 16)   0           ['batch_normalization_25[0][0]',
#                                                                   'batch_normalization_27[0][0]']
#
#  activation_16 (Activation)     (None, 32, 32, 16)   0           ['add_11[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_16[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 16)  64          ['conv2d_29[0][0]']
#  ormalization)
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 16)   2320        ['batch_normalization_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 16)  64          ['conv2d_30[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 32, 32, 16)   0           ['activation_16[0][0]',
#                                                                   'batch_normalization_29[0][0]']
#
#  activation_17 (Activation)     (None, 32, 32, 16)   0           ['add_12[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_17[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 16)  64          ['conv2d_31[0][0]']
#  ormalization)
#
#  conv2d_32 (Conv2D)             (None, 32, 32, 16)   2320        ['batch_normalization_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 16)  64          ['conv2d_32[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 32, 32, 16)   0           ['activation_17[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  activation_18 (Activation)     (None, 32, 32, 16)   0           ['add_13[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 32, 32, 32)   4640        ['activation_18[0][0]']
#
#  activation_19 (Activation)     (None, 32, 32, 32)   0           ['conv2d_33[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 32, 32, 32)  128         ['activation_19[0][0]']
#  ormalization)
#
#  conv2d_34 (Conv2D)             (None, 32, 32, 32)   9248        ['batch_normalization_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 32, 32, 32)  128         ['conv2d_34[0][0]']
#  ormalization)
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 32)   9248        ['batch_normalization_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 32, 32, 32)  128         ['conv2d_35[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 32, 32, 32)   0           ['batch_normalization_32[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  activation_20 (Activation)     (None, 32, 32, 32)   0           ['add_14[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_20[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 32, 32, 32)  128         ['conv2d_36[0][0]']
#  ormalization)
#
#  conv2d_37 (Conv2D)             (None, 32, 32, 32)   9248        ['batch_normalization_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 32, 32, 32)  128         ['conv2d_37[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 32, 32, 32)   0           ['activation_20[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  activation_21 (Activation)     (None, 32, 32, 32)   0           ['add_15[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_21[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 32, 32, 32)  128         ['conv2d_38[0][0]']
#  ormalization)
#
#  conv2d_39 (Conv2D)             (None, 32, 32, 32)   9248        ['batch_normalization_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 32, 32, 32)  128         ['conv2d_39[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 32, 32, 32)   0           ['activation_21[0][0]',
#                                                                   'batch_normalization_38[0][0]']
#
#  activation_22 (Activation)     (None, 32, 32, 32)   0           ['add_16[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 32, 32, 32)   9248        ['activation_22[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 32, 32, 32)  128         ['conv2d_40[0][0]']
#  ormalization)
#
#  conv2d_41 (Conv2D)             (None, 32, 32, 32)   9248        ['batch_normalization_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 32, 32, 32)  128         ['conv2d_41[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 32, 32, 32)   0           ['activation_22[0][0]',
#                                                                   'batch_normalization_40[0][0]']
#
#  activation_23 (Activation)     (None, 32, 32, 32)   0           ['add_17[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 32, 32, 64)   18496       ['activation_23[0][0]']
#
#  activation_24 (Activation)     (None, 32, 32, 64)   0           ['conv2d_42[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 32, 32, 64)  256         ['activation_24[0][0]']
#  ormalization)
#
#  conv2d_43 (Conv2D)             (None, 32, 32, 64)   36928       ['batch_normalization_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 32, 32, 64)  256         ['conv2d_43[0][0]']
#  ormalization)
#
#  conv2d_44 (Conv2D)             (None, 32, 32, 64)   36928       ['batch_normalization_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 32, 32, 64)  256         ['conv2d_44[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 32, 32, 64)   0           ['batch_normalization_41[0][0]',
#                                                                   'batch_normalization_43[0][0]']
#
#  activation_25 (Activation)     (None, 32, 32, 64)   0           ['add_18[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_25[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 32, 32, 64)  256         ['conv2d_45[0][0]']
#  ormalization)
#
#  conv2d_46 (Conv2D)             (None, 32, 32, 64)   36928       ['batch_normalization_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 32, 32, 64)  256         ['conv2d_46[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 32, 32, 64)   0           ['activation_25[0][0]',
#                                                                   'batch_normalization_45[0][0]']
#
#  activation_26 (Activation)     (None, 32, 32, 64)   0           ['add_19[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_26[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 32, 32, 64)  256         ['conv2d_47[0][0]']
#  ormalization)
#
#  conv2d_48 (Conv2D)             (None, 32, 32, 64)   36928       ['batch_normalization_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 32, 32, 64)  256         ['conv2d_48[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 32, 32, 64)   0           ['activation_26[0][0]',
#                                                                   'batch_normalization_47[0][0]']
#
#  activation_27 (Activation)     (None, 32, 32, 64)   0           ['add_20[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_27[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 32, 32, 64)  256         ['conv2d_49[0][0]']
#  ormalization)
#
#  conv2d_50 (Conv2D)             (None, 32, 32, 64)   36928       ['batch_normalization_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 32, 32, 64)  256         ['conv2d_50[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 32, 32, 64)   0           ['activation_27[0][0]',
#                                                                   'batch_normalization_49[0][0]']
#
#  activation_28 (Activation)     (None, 32, 32, 64)   0           ['add_21[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 64)          0           ['activation_28[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 10)           650         ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 411,466
# Trainable params: 409,514
# Non-trainable params: 1,952
# __________________________________________________________________________________________________

# %% [markdown]
# # 5. Model Training
#
# We will now train the complied model on the cifar10 dataset using the tensorflow keras `model.fit` method.

# %%
# epochs =55
epochs =100 # reduce the epoch for faster validation
history = model.fit(train_dataset, epochs=epochs, batch_size=32, 
                    validation_data=val_dataset, callbacks=[learning_rates])
# Out:
# Learning rate:  0.001
# Epoch 1/100
# 1407/1407 [==============================] - 43s 28ms/step - loss: 1.6417 - accuracy: 0.4683 - val_loss: 1.9162 - val_accuracy: 0.4444 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/100
# 1407/1407 [==============================] - 37s 26ms/step - loss: 1.2574 - accuracy: 0.6178 - val_loss: 1.3599 - val_accuracy: 0.5953 - lr: 0.0010
# Learning rate:  0.001
# Epoch 3/100
# 1407/1407 [==============================] - 37s 26ms/step - loss: 1.1126 - accuracy: 0.6673 - val_loss: 1.4833 - val_accuracy: 0.5811 - lr: 0.0010
# Learning rate:  0.001
# Epoch 4/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 1.0187 - accuracy: 0.7032 - val_loss: 1.1294 - val_accuracy: 0.6776 - lr: 0.0010
# Learning rate:  0.001
# Epoch 5/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.9493 - accuracy: 0.7309 - val_loss: 1.1121 - val_accuracy: 0.6776 - lr: 0.0010
# Learning rate:  0.001
# Epoch 6/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.9029 - accuracy: 0.7471 - val_loss: 1.2904 - val_accuracy: 0.6182 - lr: 0.0010
# Learning rate:  0.001
# Epoch 7/100
# 1407/1407 [==============================] - 36s 25ms/step - loss: 0.8699 - accuracy: 0.7608 - val_loss: 1.0076 - val_accuracy: 0.7153 - lr: 0.0010
# Learning rate:  0.001
# Epoch 8/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.8362 - accuracy: 0.7742 - val_loss: 0.9529 - val_accuracy: 0.7336 - lr: 0.0010
# Learning rate:  0.001
# Epoch 9/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.8167 - accuracy: 0.7809 - val_loss: 1.3812 - val_accuracy: 0.6353 - lr: 0.0010
# Learning rate:  0.001
# Epoch 10/100
# 1407/1407 [==============================] - 37s 26ms/step - loss: 0.7955 - accuracy: 0.7908 - val_loss: 0.9683 - val_accuracy: 0.7431 - lr: 0.0010
# Learning rate:  0.001
# Epoch 11/100
# 1407/1407 [==============================] - 37s 26ms/step - loss: 0.7723 - accuracy: 0.7999 - val_loss: 1.0523 - val_accuracy: 0.7160 - lr: 0.0010
# Learning rate:  0.001
# Epoch 12/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.7610 - accuracy: 0.8048 - val_loss: 1.0330 - val_accuracy: 0.7213 - lr: 0.0010
# Learning rate:  0.001
# Epoch 13/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.7487 - accuracy: 0.8094 - val_loss: 0.9959 - val_accuracy: 0.7420 - lr: 0.0010
# Learning rate:  0.001
# Epoch 14/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.7306 - accuracy: 0.8174 - val_loss: 0.8935 - val_accuracy: 0.7711 - lr: 0.0010
# Learning rate:  0.001
# Epoch 15/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.7202 - accuracy: 0.8202 - val_loss: 0.9065 - val_accuracy: 0.7700 - lr: 0.0010
# Learning rate:  0.001
# Epoch 16/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.7154 - accuracy: 0.8217 - val_loss: 1.0968 - val_accuracy: 0.7369 - lr: 0.0010
# Learning rate:  0.001
# Epoch 17/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.7065 - accuracy: 0.8255 - val_loss: 1.0644 - val_accuracy: 0.7307 - lr: 0.0010
# Learning rate:  0.001
# Epoch 18/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6946 - accuracy: 0.8311 - val_loss: 1.2286 - val_accuracy: 0.7033 - lr: 0.0010
# Learning rate:  0.001
# Epoch 19/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6862 - accuracy: 0.8345 - val_loss: 1.7901 - val_accuracy: 0.6151 - lr: 0.0010
# Learning rate:  0.001
# Epoch 20/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6846 - accuracy: 0.8338 - val_loss: 0.9635 - val_accuracy: 0.7702 - lr: 0.0010
# Learning rate:  0.001
# Epoch 21/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6716 - accuracy: 0.8399 - val_loss: 0.9452 - val_accuracy: 0.7604 - lr: 0.0010
# Learning rate:  0.001
# Epoch 22/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6668 - accuracy: 0.8425 - val_loss: 1.0335 - val_accuracy: 0.7391 - lr: 0.0010
# Learning rate:  0.001
# Epoch 23/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6586 - accuracy: 0.8441 - val_loss: 1.1563 - val_accuracy: 0.7160 - lr: 0.0010
# Learning rate:  0.001
# Epoch 24/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6524 - accuracy: 0.8460 - val_loss: 0.7962 - val_accuracy: 0.8011 - lr: 0.0010
# Learning rate:  0.001
# Epoch 25/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6486 - accuracy: 0.8490 - val_loss: 0.8608 - val_accuracy: 0.7940 - lr: 0.0010
# Learning rate:  0.001
# Epoch 26/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6453 - accuracy: 0.8507 - val_loss: 0.9335 - val_accuracy: 0.7611 - lr: 0.0010
# Learning rate:  0.001
# Epoch 27/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6451 - accuracy: 0.8509 - val_loss: 1.1048 - val_accuracy: 0.7376 - lr: 0.0010
# Learning rate:  0.001
# Epoch 28/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6295 - accuracy: 0.8551 - val_loss: 1.0346 - val_accuracy: 0.7578 - lr: 0.0010
# Learning rate:  0.001
# Epoch 29/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6287 - accuracy: 0.8565 - val_loss: 0.9187 - val_accuracy: 0.7664 - lr: 0.0010
# Learning rate:  0.001
# Epoch 30/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6293 - accuracy: 0.8561 - val_loss: 0.9639 - val_accuracy: 0.7744 - lr: 0.0010
# Learning rate:  0.001
# Epoch 31/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6276 - accuracy: 0.8585 - val_loss: 1.0010 - val_accuracy: 0.7653 - lr: 0.0010
# Learning rate:  0.001
# Epoch 32/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6215 - accuracy: 0.8605 - val_loss: 0.9782 - val_accuracy: 0.7700 - lr: 0.0010
# Learning rate:  0.001
# Epoch 33/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6200 - accuracy: 0.8621 - val_loss: 1.1655 - val_accuracy: 0.7247 - lr: 0.0010
# Learning rate:  0.001
# Epoch 34/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6078 - accuracy: 0.8654 - val_loss: 1.1494 - val_accuracy: 0.7262 - lr: 0.0010
# Learning rate:  0.001
# Epoch 35/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6109 - accuracy: 0.8652 - val_loss: 1.1737 - val_accuracy: 0.7269 - lr: 0.0010
# Learning rate:  0.001
# Epoch 36/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6092 - accuracy: 0.8650 - val_loss: 0.9946 - val_accuracy: 0.7509 - lr: 0.0010
# Learning rate:  0.001
# Epoch 37/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6067 - accuracy: 0.8650 - val_loss: 1.0906 - val_accuracy: 0.7424 - lr: 0.0010
# Learning rate:  0.001
# Epoch 38/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.6013 - accuracy: 0.8663 - val_loss: 0.9516 - val_accuracy: 0.7653 - lr: 0.0010
# Learning rate:  0.001
# Epoch 39/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.5976 - accuracy: 0.8685 - val_loss: 1.2364 - val_accuracy: 0.7171 - lr: 0.0010
# Learning rate:  0.001
# Epoch 40/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.5944 - accuracy: 0.8701 - val_loss: 0.7706 - val_accuracy: 0.8087 - lr: 0.0010
# Learning rate:  0.001
# Epoch 41/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.5930 - accuracy: 0.8716 - val_loss: 1.4834 - val_accuracy: 0.6902 - lr: 0.0010
# Learning rate:  0.0001
# Epoch 42/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.4927 - accuracy: 0.9061 - val_loss: 0.5514 - val_accuracy: 0.8916 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 43/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.4498 - accuracy: 0.9206 - val_loss: 0.5441 - val_accuracy: 0.8909 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 44/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.4287 - accuracy: 0.9269 - val_loss: 0.5264 - val_accuracy: 0.8960 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 45/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.4152 - accuracy: 0.9295 - val_loss: 0.5251 - val_accuracy: 0.8933 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 46/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.4007 - accuracy: 0.9328 - val_loss: 0.5315 - val_accuracy: 0.8969 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 47/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.3882 - accuracy: 0.9352 - val_loss: 0.5128 - val_accuracy: 0.8982 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 48/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.3778 - accuracy: 0.9390 - val_loss: 0.5392 - val_accuracy: 0.8909 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 49/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.3714 - accuracy: 0.9386 - val_loss: 0.5261 - val_accuracy: 0.8938 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 50/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.3636 - accuracy: 0.9418 - val_loss: 0.5219 - val_accuracy: 0.8967 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 51/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.3560 - accuracy: 0.9409 - val_loss: 0.5138 - val_accuracy: 0.8949 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 52/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.3476 - accuracy: 0.9438 - val_loss: 0.5104 - val_accuracy: 0.8971 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 53/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.3416 - accuracy: 0.9461 - val_loss: 0.5265 - val_accuracy: 0.8944 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 54/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.3347 - accuracy: 0.9475 - val_loss: 0.5139 - val_accuracy: 0.8980 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 55/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.3277 - accuracy: 0.9490 - val_loss: 0.5003 - val_accuracy: 0.8982 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 56/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.3211 - accuracy: 0.9511 - val_loss: 0.5029 - val_accuracy: 0.8980 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 57/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.3173 - accuracy: 0.9509 - val_loss: 0.5150 - val_accuracy: 0.8944 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 58/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.3083 - accuracy: 0.9542 - val_loss: 0.5087 - val_accuracy: 0.8958 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 59/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.3060 - accuracy: 0.9540 - val_loss: 0.5106 - val_accuracy: 0.8931 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 60/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2992 - accuracy: 0.9560 - val_loss: 0.5007 - val_accuracy: 0.8984 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 61/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2940 - accuracy: 0.9571 - val_loss: 0.5043 - val_accuracy: 0.8951 - lr: 1.0000e-04
# Learning rate:  1e-05
# Epoch 62/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2829 - accuracy: 0.9608 - val_loss: 0.4946 - val_accuracy: 0.8998 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 63/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2780 - accuracy: 0.9626 - val_loss: 0.4943 - val_accuracy: 0.9009 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 64/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2720 - accuracy: 0.9646 - val_loss: 0.4934 - val_accuracy: 0.8984 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 65/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2705 - accuracy: 0.9657 - val_loss: 0.4936 - val_accuracy: 0.9011 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 66/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2707 - accuracy: 0.9652 - val_loss: 0.4928 - val_accuracy: 0.9004 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 67/100
# 1407/1407 [==============================] - 37s 26ms/step - loss: 0.2704 - accuracy: 0.9645 - val_loss: 0.4921 - val_accuracy: 0.9018 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 68/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2656 - accuracy: 0.9674 - val_loss: 0.4923 - val_accuracy: 0.9013 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 69/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2684 - accuracy: 0.9665 - val_loss: 0.4918 - val_accuracy: 0.9016 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 70/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2690 - accuracy: 0.9652 - val_loss: 0.4914 - val_accuracy: 0.8991 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 71/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2665 - accuracy: 0.9672 - val_loss: 0.4952 - val_accuracy: 0.9007 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 72/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2631 - accuracy: 0.9677 - val_loss: 0.4940 - val_accuracy: 0.9013 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 73/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2653 - accuracy: 0.9673 - val_loss: 0.4947 - val_accuracy: 0.8996 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 74/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2629 - accuracy: 0.9676 - val_loss: 0.4929 - val_accuracy: 0.9007 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 75/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2621 - accuracy: 0.9671 - val_loss: 0.4963 - val_accuracy: 0.8982 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 76/100
# 1407/1407 [==============================] - 37s 26ms/step - loss: 0.2641 - accuracy: 0.9665 - val_loss: 0.4983 - val_accuracy: 0.8984 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 77/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2598 - accuracy: 0.9679 - val_loss: 0.4973 - val_accuracy: 0.8987 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 78/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2604 - accuracy: 0.9673 - val_loss: 0.4969 - val_accuracy: 0.8996 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 79/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2596 - accuracy: 0.9684 - val_loss: 0.4939 - val_accuracy: 0.8987 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 80/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2579 - accuracy: 0.9684 - val_loss: 0.4948 - val_accuracy: 0.9000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 81/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2591 - accuracy: 0.9680 - val_loss: 0.4966 - val_accuracy: 0.9002 - lr: 1.0000e-05
# Learning rate:  5e-07
# Epoch 82/100
# 1407/1407 [==============================] - 37s 26ms/step - loss: 0.2563 - accuracy: 0.9698 - val_loss: 0.4971 - val_accuracy: 0.9000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 83/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2559 - accuracy: 0.9701 - val_loss: 0.4980 - val_accuracy: 0.9002 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 84/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2547 - accuracy: 0.9701 - val_loss: 0.4981 - val_accuracy: 0.9007 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 85/100
# 1407/1407 [==============================] - 37s 26ms/step - loss: 0.2557 - accuracy: 0.9699 - val_loss: 0.4972 - val_accuracy: 0.9000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 86/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2554 - accuracy: 0.9695 - val_loss: 0.4982 - val_accuracy: 0.9002 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 87/100
# 1407/1407 [==============================] - 37s 26ms/step - loss: 0.2556 - accuracy: 0.9695 - val_loss: 0.4976 - val_accuracy: 0.9004 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 88/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2543 - accuracy: 0.9705 - val_loss: 0.4974 - val_accuracy: 0.9002 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 89/100
# 1407/1407 [==============================] - 37s 26ms/step - loss: 0.2550 - accuracy: 0.9699 - val_loss: 0.4974 - val_accuracy: 0.9004 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 90/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2566 - accuracy: 0.9696 - val_loss: 0.4978 - val_accuracy: 0.9007 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 91/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2560 - accuracy: 0.9701 - val_loss: 0.4972 - val_accuracy: 0.9004 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 92/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2551 - accuracy: 0.9695 - val_loss: 0.4975 - val_accuracy: 0.9004 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 93/100
# 1407/1407 [==============================] - 37s 26ms/step - loss: 0.2534 - accuracy: 0.9713 - val_loss: 0.4979 - val_accuracy: 0.9004 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 94/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2545 - accuracy: 0.9706 - val_loss: 0.4975 - val_accuracy: 0.9007 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 95/100
# 1407/1407 [==============================] - 37s 26ms/step - loss: 0.2533 - accuracy: 0.9708 - val_loss: 0.4972 - val_accuracy: 0.9009 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 96/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2561 - accuracy: 0.9684 - val_loss: 0.4975 - val_accuracy: 0.9007 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 97/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2553 - accuracy: 0.9699 - val_loss: 0.4975 - val_accuracy: 0.9009 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 98/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2555 - accuracy: 0.9692 - val_loss: 0.4967 - val_accuracy: 0.9004 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 99/100
# 1407/1407 [==============================] - 36s 26ms/step - loss: 0.2540 - accuracy: 0.9702 - val_loss: 0.4974 - val_accuracy: 0.9007 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 100/100
# 1407/1407 [==============================] - 37s 26ms/step - loss: 0.2535 - accuracy: 0.9706 - val_loss: 0.4968 - val_accuracy: 0.9009 - lr: 5.0000e-07

# %% [markdown]
# We will plot the loss and accuracy for the training and validation data sets.

# %%
print(history.history.keys())
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,2.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %% [markdown]
# # 6. Model Testing
# We will iterate through the test data and analyse the results using tools from sklearn. We create a classification report, a confusion matrix and also plot a few examples from the test set.

# %% [markdown]
# Iterate through n_test batches and store the predicted and ground truth labels in numpy arrays.

# %%
n_test = 100 # number of batches to use
store_predictions = []
store_labels = []
for image_batch,label_batch in test_dataset.take(n_test):
    predictions = model.predict_on_batch(image_batch) 
    predictions = tf.math.argmax(predictions,axis=1)
    store_predictions.append(predictions)
    store_labels.append(label_batch)
y_pred = np.squeeze(np.reshape(store_predictions,(1,n_test*batch_size)))
y_true = np.squeeze(np.reshape(store_labels,(1,n_test*batch_size)))

# %% [markdown]
# Create and plot a confusion matrix.

# %%
#https://scikit-learn.org/0.16/auto_examples/model_selection/plot_confusion_matrix.html
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, y_pred)
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(label_str))
    plt.xticks(tick_marks, label_str, rotation=45)
    plt.yticks(tick_marks, label_str)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm)

# %% [markdown]
# Generate & print the classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=label_str))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.90      0.93      0.91       337
#   automobile       0.95      0.97      0.96       338
#         bird       0.86      0.88      0.87       306
#          cat       0.82      0.78      0.80       323
#         deer       0.89      0.91      0.90       297
#          dog       0.88      0.85      0.86       325
#         frog       0.88      0.93      0.91       307
#        horse       0.95      0.90      0.92       317
#         ship       0.95      0.94      0.95       326
#        truck       0.93      0.93      0.93       324
#
#     accuracy                           0.90      3200
#    macro avg       0.90      0.90      0.90      3200
# weighted avg       0.90      0.90      0.90      3200

# %% [markdown]
# Plot some test images and predicted labels.

# %%
#Retrieve a batch of images from the test set
image_batch, label_batch = test_dataset.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch)
print(np.shape(predictions))
# Apply a sigmoid since our model returns logits
predictions = tf.math.argmax(predictions,axis=1)
print(np.shape(predictions))
print('Predictions:\n', predictions.numpy())


i=0
n_plots = 12 # number of plots
f, axarr = plt.subplots(1,n_plots,figsize=(20,10))

for image in image_batch[0:n_plots,:,:,:]:  # Only take a single example
  axarr[i].imshow(image[:,:,:]+0.5)
  axarr[i].axis('off')
  
  color = ('black' if predictions[i] == int(label_batch[i]) else 'red') 
  axarr[i].set_title(label_str[int(predictions[i])],fontsize='small', color=color)
  i = i+1
# Out:
# (32, 10)
# (32,)
# Predictions:
#  [7 0 6 9 5 1 7 0 5 2 7 2 7 9 5 8 8 8 7 9 4 2 3 5 0 8 2 8 1 8 2 0]

# %% [markdown]
# # Please Leave a note here explaining your approach/results for the e-moderator.

# %% [markdown]
# My intial approach is to create a deep CNN for reach a good quality of prediction, the first network I was building was a ResNet with 50 layers, this create over 27 Millionr parameter, the network show a great learning, but a very bad generalization, the real accurancy it was around 80%, but with an high level of overfitting.
# From that network I try to reduce the overfitting, this is done reduce the complexity of the network, it was my first approach, and after adding some regulation, an L2, and a learning rate. At the same time follow the suggestion of my peers, I refactor the architecture of my network.
# This help to improve the generalizzation but it was not enough to reach the 90% required.
# The next was to add an image argumentation, this help a lot to reduce the overfitting and reach a good 83% with less parameter, I have passed to 27M to 270K, this make the network more trainable on my environment, I use Colab and complex network need more time to train.
# This approach as well it was not good enough, so I decide to apply a different learning steps, I create a function for that and reduce the amout of epoch first to change learning rate, with an epoch of 100 and the new learning steps, the CNN was able to perform a better normalizzation and achieve the result of 90% request.
# The graph clearly show, a change on the learning steps help to better generalize the learning, I think have a different learning rate can really improve the capacity of learning of the CNN.
